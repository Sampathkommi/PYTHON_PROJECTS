# %% [markdown]
# <a href="https://colab.research.google.com/github/Sampathkommi/PYTHON_PROJECTS/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to the tip calculator")
bill = float(input("what was the total bill? $"))
tip = int(input("how much tip would you like to give? 10, 12, or 15? "))
people  = input("how many people to split the bill? ")
tip_as_percent = tip / 100
total_tip_amount = bill * tip_as_percent
total_bill = bill + total_tip_amount
bill_per_person = total_bill / int(people)
final_amount = round(bill_per_person, 2)
print(f"each person should pay: ${final_amount}")
# Out:
# welcome to the tip calculator
# what was the total bill? $200
# how much tip would you like to give? 10, 12, or 15? 10
# how many people to split the bill? 3
# each person should pay: $73.33

# %%
from google.colab import drive
drive.mount('/content/drive')
